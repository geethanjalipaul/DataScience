# %% [markdown]
# <a href="https://colab.research.google.com/github/geethanjalipaul/DataScience/blob/master/program13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import sklearn
dataset=pd.read_csv('Mall_Customers.csv')
X=dataset.iloc[:, [3, 4]].values
from sklearn.cluster import KMeans
wcss=[]
for i in range(1, 11):
  kmeans=KMeans(n_clusters=i,init='k-means++', random_state = 42)
  kmeans.fit(X)
  wcss.append(kmeans.inertia_)
plt.plot(range(1, 11), wcss)
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()
plt.plot(range(1, 11), wcss)
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()
kmeans=KMeans(n_clusters = 5, init = "k-meanst++", random_state = 42)
y_kmeans=kmeans.fit_predict(X)
print(y_kmeans)
plt.scatter(X[y_kmeans==0,0], X[y_kmeans==0,1], s = 50, c='red', label = "Cluster1")
plt.scatter(X[y_kmeans==1,0], X[y_kmeans==1,1], s= 50, c = "blue", label = "Cluster2")
plt.scatter(X[y_kmeans==2,0], X[y_kmeans==2,1], s= 50, c = 'green', label = 'Cluster3')
plt.scatter(X[y_kmeans==3,0], X[y_kmeans==3,1], s=50, c='violet', label="Cluster4") 
plt.scatter(X[y_kmeans==4,0], X[y_kmeans==3,1], s=50, c='yellow', label="Cluster5")
plt.scatter(kmeans.cluster_centers_[:,0],kmeans.cluster_centers_[:,1],s=100,marker='x',c ='red', label= 'Centroids')
plt.xlabel('Annual Income')
plt.ylabel('Spending Score (1-100)')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-bfb0447dc70a> in <module>
#      20 plt.show()
#      21 kmeans=KMeans(n_clusters = 5, init = "k-meanst++", random_state = 42)
# ---> 22 y_kmeans=kmeans.fit_predict(X)
#      23 print(y_kmeans)
#      24 plt.scatter(X[y_kmeans==0,0], X[y_kmeans==0,1], s = 50, c='red', label = "Cluster1")
#
# /usr/local/lib/python3.7/dist-packages/sklearn/cluster/_kmeans.py in fit_predict(self, X, y, sample_weight)
#    1253             Index of the cluster each sample belongs to.
#    1254         """
# -> 1255         return self.fit(X, sample_weight=sample_weight).labels_
#    1256
#    1257     def fit_transform(self, X, y=None, sample_weight=None):
#
# /usr/local/lib/python3.7/dist-packages/sklearn/cluster/_kmeans.py in fit(self, X, y, sample_weight)
#    1144         )
#    1145
# -> 1146         self._check_params(X)
#    1147         random_state = check_random_state(self.random_state)
#    1148         sample_weight = _check_sample_weight(sample_weight, X, dtype=X.dtype)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/cluster/_kmeans.py in _check_params(self, X)
#     977         ):
#     978             raise ValueError(
# --> 979                 "init should be either 'k-means++', 'random', a ndarray or a "
#     980                 f"callable, got '{self.init}' instead."
#     981             )
#
# ValueError: init should be either 'k-means++', 'random', a ndarray or a callable, got 'k-meanst++' instead.
